# %% [markdown]
# #### НОВАЯ АРХИТЕКТУРА МАППИНГА

# %% [markdown]
# #### Версия 5,6

# %%
import os
import re
import json
import time
import pandas as pd
from collections import Counter
from ast import literal_eval
import requests
import numpy as np
import urllib3
import backoff
import math
from datetime import datetime

api_url = "https://api.mistral.ai/v1/chat/completions"
model_name = "mistral-small-latest"
api_key = ''
HEADERS = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}
# Отключаем предупреждения HTTPS
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# ================== ВСПОМОГАТЕЛЬНЫЕ ФУНКЦИИ ==================

def safe_literal_eval(x):
    if isinstance(x, list):
        return x
    elif isinstance(x, str):
        try:
            return literal_eval(x)
        except:
            return []
    else:
        return []

def extract_json_from_markdown(content):
    """Извлекает JSON из markdown формата с бэктиками"""
    # Убираем бэктики и маркдаун
    content = re.sub(r'^```json\s*', '', content.strip())
    content = re.sub(r'^```\s*', '', content)
    content = re.sub(r'```$', '', content)
    return content.strip()

def safe_parse_json(content: str) -> dict:
    # Извлекаем JSON из markdown если нужно
    content = extract_json_from_markdown(content)
    
    # Приводим кавычки к стандартным
    content = content.replace("“", '"').replace("”", '"').replace("‘", "'").replace("’", "'")
    # Убираем невидимые символы
    content = re.sub(r"[\u200B-\u200D\uFEFF]", "", content)

    try:
        # Убираем дубликаты ключей (оставляем последнее)
        def no_duplicate_pairs(pairs):
            d = {}
            for k, v in pairs:
                d[k] = v
            return d

        return json.loads(content, object_pairs_hook=no_duplicate_pairs)
    except Exception as e:
        print("⚠️ Не удалось распарсить JSON:", e)
        print("📋 Ответ как есть (первые 500 символов):", content[:500], "…")
        return {"anchors": [], "mapping": {}}

@backoff.on_exception(backoff.expo, 
                     (requests.exceptions.RequestException, ValueError),
                     max_tries=5,
                     max_time=60)
def send_request_to_llm(api_url, prompt, model_name, api_key, temperature=0.2, max_tokens=8192, delay=20):
    time.sleep(delay)
    payload = {
        "model": model_name,
        "messages": [
            {"role": "system", "content": "Ты — ИИ для обработки и структурирования навыков в IT-рекрутинге. Отвечай ТОЛЬКО JSON без объяснений."},
            {"role": "user", "content": prompt}
        ],
        "temperature": temperature,
        "max_tokens": max_tokens,
        "response_format": {"type": "json_object"}  # Принудительно запрашиваем JSON
    }
    headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}
    
    try:
        resp = requests.post(api_url, json=payload, headers=headers, timeout=120, verify=False)
        
        if resp.status_code == 429:
            # Rate limiting - ждем подольше
            wait_time = 10
            print(f"⏳ Rate limit exceeded, waiting {wait_time} seconds...")
            time.sleep(wait_time)
            raise requests.exceptions.RequestException("Rate limit exceeded")
        
        if resp.status_code != 200:
            raise ValueError(f"Ошибка API: {resp.status_code} {resp.text}")
        
        resp_json = resp.json()
        content = resp_json["choices"][0]["message"]["content"]
        
        if not content or not content.strip():
            print("⚠️ Модель вернула пустой content")
            return {}
        
        return safe_parse_json(content)
        
    except requests.exceptions.RequestException as e:
        print(f"❌ Ошибка сети: {e}")
        raise
    except Exception as e:
        print(f"❌ Неожиданная ошибка: {e}")
        raise

def call_llm(api_url, prompt, model_name, api_key, retries=3):
    for i in range(retries):
        try:
            print(f"🔄 Попытка {i+1} для запроса к LLM")
            data = send_request_to_llm(api_url, prompt, model_name, api_key)
            
            if isinstance(data, dict) and data:
                print(f"✅ Успешный JSON ответ (попытка {i+1})")
                return data
            else:
                print(f"⚠️ Пустой или невалидный JSON (попытка {i+1})")
                
        except Exception as e:
            print(f"❌ Ошибка в call_llm (попытка {i+1}): {e}")
            if i == retries - 1:  # Последняя попытка
                return {}
        
        # Увеличиваем задержку между попытками
        time.sleep(2 * (i + 1))
    
    print(f"❌ Все {retries} попыток провалились")
    return {}

# ================== ОСНОВНЫЕ ЭТАПЫ ==================

# 1. Чанк → якори + маппинг
def discover_chunk_anchors_and_map(position, chunk_skills, n, api_url, model_name, api_key):
    prompt = f"""
Профессия: {position}
Навыки: {chunk_skills}

1. Выдели до {n} якорей (категорий) только из этих навыков. 
   - Якоря должны быть конкретными технологиями или инструментами (SQL, Python, Tableau) по заданной професии
   - Избегай общих понятий (Анализ, Данные, Программирование)
   - Форма должна быть каноничной (короткая, общепринятая)
   - НЕ ПОВТОРЯЙ одинаковые якоря
2. Замапь все навыки из списка к выбранным якорям, если они являются синонимами. 
   - Если навык не подходит ни к одному якорю — оставь его неизменным
   - Возможны случаи , что у якоря нет синонимов 

ВЕРНИ СТРОГО В ФОРМАТЕ JSON БЕЗ ЛИШНИХ СИМВОЛОВ И БЕЗ ПОВТОРЕНИЙ.
Формат ответа ДОЛЖЕН БЫТЬ:
{{
  "anchors": ["якорь1", "якорь2", ...],
  "mapping": {{"skill1": "anchor1", "skill2": "skill2"}}
}}
"""
    response = call_llm(api_url, prompt, model_name, api_key)
    anchors = response.get("anchors", [])
    mapping = response.get("mapping", {})

    # 🔑 страховка: все навыки из чанка должны быть в mapping
    for s in chunk_skills:
        if s not in mapping:
            mapping[s] = s

    return anchors, mapping

# 2. Глобальная нормализация якорей (с добавленной защитой)
def normalize_global_anchors(position, all_local_anchors, api_url, model_name, api_key):
    if not all_local_anchors:
        print(f"⚠️  Нет локальных якорей для {position}")
        return [], {}
    
    # Если якорей мало, просто возвращаем их как есть
    if len(all_local_anchors) <= 10:
        base_anchors = list(set(all_local_anchors))
        mapping = {k: k for k in all_local_anchors}
        return base_anchors, mapping
    
    prompt = f"""
Для професии {position} собраны локальные якори-навыки (skills) : {all_local_anchors}

1. Выдели среди них базовые каноничные скилы base_anchors професии (с общепринятыми названиями).
2. Сгруппируй синонимы к этим базовым, если синонимы являются очень близкими по смыслу вариантами базового навыка или вариантами написания базового навыка.

Важно:
- Канонические скилы выбираются только из скиска всех якорей-навыков, не придумывай новые
- Если у базового якоря нет синонима - верни как есть.
- Каждый локальный якорь должен присутствовать в mapping.
- ВЕРНИ СТРОГО В ФОРМАТЕ JSON БЕЗ ЛИШНИХ СИМВОЛОВ.

Формат ответа ДОЛЖЕН БЫТЬ:
{{
  "base_anchors": ["base_anchor1", "base_anchor2", ...],
  "mapping": {{"локальный_якорь1": "base_anchor1", "локальный_якорь2": "base_anchor2", "локальный_якорь3": "base_anchor2", "локальный_якорь4": "локальный_якорь4",...}}
}}
"""
    
    try:
        response = call_llm(api_url, prompt, model_name, api_key)
        
        base_anchors = response.get("base_anchors", [])
        mapping = response.get("mapping", {})
        
        if not base_anchors:
            print(f"⚠️  Пустые base_anchors для {position}, используем fallback")
            base_anchors = list(set(all_local_anchors))
            mapping = {k: k for k in all_local_anchors}
        
        # Убедимся, что все локальные якори есть в mapping
        for anchor in all_local_anchors:
            if anchor not in mapping:
                mapping[anchor] = anchor
        
        print(f"✅ Final base_anchors для {position}: {len(base_anchors)} якорей")
        return base_anchors, mapping
        
    except Exception as e:
        print(f"❌ Ошибка в normalize_global_anchors для {position}: {e}")
        # Fallback: используем уникальные локальные якори
        base_anchors = list(set(all_local_anchors))
        mapping = {k: k for k in all_local_anchors}
        return base_anchors, mapping

# 3. Маппинг оставшихся скиллов к базовым якорям
def map_remaining_skills_to_base(position, base_anchors, remaining_skills, api_url, model_name, api_key, chunk_size=300):
    final_mapping = {}
    chunks = [remaining_skills[i:i+chunk_size] for i in range(0, len(remaining_skills), chunk_size)]
    
    for i, chunk in enumerate(chunks, 1):
        print(f"📦 Обрабатываю чанк {i}/{len(chunks)} для {position} ({len(chunk)} навыков)")
        
        prompt = f"""
Профессия: {position}
Базовые якори-навыки: {base_anchors}

Навыки: {chunk}

Замапь навыки к базовым якорям, если они являются синонимами или вариантами навыка близкими по смыслу.
Если навык не подходит ни к одному якорю — замапь его к 'Other'.
ВЕРНИ СТРОГО В ФОРМАТЕ JSON БЕЗ ЛИШНИХ СИМВОЛОВ.

Формат ответа ДОЛЖЕН БЫТЬ:
{{
  "mapping": {{"skill1": "anchor/Other", ...}}
}}
"""
        response = call_llm(api_url, prompt, model_name, api_key)
        mapping = response.get("mapping", {})

        # 🔑 страховка: все скиллы из чанка должны попасть в mapping
        for s in chunk:
            if s not in mapping:
                mapping[s] = s

        final_mapping.update(mapping)
    
    return final_mapping

# 4. Полный процесс для одной позиции
def process_position_pipeline(position, skills, n, api_url, model_name, api_key, chunk_size=200):
    # Считаем частоту навыков
    skill_counts = {}
    for skill in skills:
        # Пропускаем вложенные списки
        if isinstance(skill, list):
            print(f"⚠️  Пропускаем вложенный список: {skill}")
            continue
        skill_counts[skill] = skill_counts.get(skill, 0) + 1
    
    # Сортируем навыки по убыванию частоты
    unique_skills = sorted(skill_counts, key=skill_counts.get, reverse=True)
    
     
    print(f"🎯 Начинаю обработку {position}: {len(unique_skills)} уникальных навыков")
    
    chunks = [unique_skills[i:i+chunk_size] for i in range(0, len(unique_skills), chunk_size)]
    
    all_local_anchors, all_local_mapping = [], {}
    for i, chunk in enumerate(chunks, 1):
        print(f"🔍 Обрабатываю чанк {i}/{len(chunks)} для {position}")
        anchors, mapping = discover_chunk_anchors_and_map(position, chunk, n, api_url, model_name, api_key)
        all_local_anchors.extend(anchors)
        all_local_mapping.update(mapping)

    base_anchors, anchor_mapping = normalize_global_anchors(position, all_local_anchors, api_url, model_name, api_key)
    
    # ДОБАВЛЕНО: защита от пустых base_anchors
    if not base_anchors:
        base_anchors = list(set(all_local_anchors))
        anchor_mapping = {k: k for k in all_local_anchors}

    # нормализуем все маппинги
    normalized_mapping = {}
    for k, v in all_local_mapping.items():
        normalized_mapping[k] = anchor_mapping.get(v, v)

    # Находим навыки, которые нужно дополнительно обработать
    remaining_skills = []
    for skill in unique_skills:
        mapped_value = normalized_mapping.get(skill, skill)
        if mapped_value not in base_anchors and mapped_value == skill:
            remaining_skills.append(skill)

    # маппим остатки
    extra_mapping = {}
    if remaining_skills:
        print(f"📋 Дополнительная обработка {len(remaining_skills)} навыков для {position}")
        extra_mapping = map_remaining_skills_to_base(position, base_anchors, remaining_skills, api_url, model_name, api_key)

    # объединяем все маппинги
    final_mapping = {**normalized_mapping, **extra_mapping}

    # страховка: каждый навык должен остаться
    for s in unique_skills:
        if s not in final_mapping:
            final_mapping[s] = s

    # Статистика
    stats = {
        "total_skills": len(unique_skills),
        "mapped": sum(1 for v in final_mapping.values() if v in base_anchors),
        "unmapped": sum(1 for k, v in final_mapping.items() if v == k),
        "base_anchors": len(base_anchors),
        "remaining_sent": len(remaining_skills)
    }

    return final_mapping, base_anchors, stats

# 5. Обработка всех позиций в датафрейме
def process_all_positions(df, api_url, model_name, position_to_n, output_file, api_key, chunk_size=200):
    results = []
    positions = df["position"].unique()
    
    for i, pos in enumerate(positions, 1):
        print(f"\n{'='*50}")
        print(f"🚀 Обработка позиции {i}/{len(positions)}: {pos}")
        print(f"{'='*50}")
        
        all_skills = []
        for sublist in df.loc[df["position"] == pos, "skills"]:
            all_skills.extend(safe_literal_eval(sublist))

        n = position_to_n.get(pos, 30)  # Уменьшил дефолтное значение для экономии токенов
        
        try:
            mapping, anchors, stats = process_position_pipeline(pos, all_skills, n, api_url, model_name, api_key, chunk_size)
            
            results.append({
                "position": pos,
                "anchors": json.dumps(anchors, ensure_ascii=False),
                "mapping": json.dumps(mapping, ensure_ascii=False),
                "stats": json.dumps(stats, ensure_ascii=False)
            })
            
            print(f"✅ {pos}: {stats}")
            
            # Сохраняем промежуточные результаты после каждой позиции
            temp_df = pd.DataFrame(results)
            temp_df.to_csv(f"temp_1_{output_file}", index=False)
            
        except Exception as e:
            print(f"❌ Критическая ошибка при обработке {pos}: {e}")
            # Сохраняем то, что успели обработать
            if results:
                temp_df = pd.DataFrame(results)
                temp_df.to_csv(f"partial_{output_file}", index=False)
            continue

    pd.DataFrame(results).to_csv(output_file, index=False)
    print(f"Готово. Сохранено в {output_file}")

# %%
# задаём для каких позиций сколько категорий хотим оставить
position_to_n = {
    'Специалист технической поддержки': 100,
    'Системный администратор': 100,
    'Дизайнер, художник': 100,
    'Тестировщик': 100,
    'Аналитик':	75,
    'Руководитель проектов': 70,
    'Специалист по информационной безопасности': 100,
    'Системный аналитик': 100,
    'Менеджер продукта': 100,
    'Системный инженер': 100,
    'Бизнес-аналитик': 100,
    'BI-аналитик, аналитик данных': 100,
    'Сетевой инженер': 50,
    'Руководитель группы разработки': 50,
    'Методолог': 100,
    'Технический писатель': 50,
    'Дата-сайентист':	50,
    'Технический директор (CTO)': 30,
    'Продуктовый аналитик': 50,
    'Арт-директор, креативный директор':	50,
    'Руководитель отдела аналитики':	50,
    'Директор по информационным технологиям (CIO)':	50,
    'Программист, разработчик': 100,
    'DevOps-инженер': 75 
    
}


input_file = "data/stage_5_df_train_result.csv"

output_file = "stage_5_df_train_result_skills_mapping_V6_2.csv"
#partial_file = "skills_mapping_mistral_partial.csv"

# === загружаем датафрейм ===
df = pd.read_csv(input_file)
# === отфильтруем ==#
df = df[df['position'].isin(position_to_n.keys())]

df["skills"] = df["skills"].apply(safe_literal_eval)   # приводим к list

# === запускаем обработку ===
process_all_positions(
    df=df,
    api_url=api_url,
    model_name=model_name,
    position_to_n=position_to_n,
    output_file=output_file,
    #partial_file=partial_file,
    api_key=api_key,
    chunk_size=600 
)
# Out:
# ==================================================
# 🚀 Обработка позиции 1/2: DevOps-инженер
# ==================================================
# 🎯 Начинаю обработку DevOps-инженер: 1878 уникальных навыков
# 🔍 Обрабатываю чанк 1/4 для DevOps-инженер
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 559 column 12 (char 22463)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": ["Terraform", "Ansible", "Helm", "Kubernetes", "OpenShift", "Docker", "Podman", "Prometheus", "Grafana", "Zabbix", "Bash", "Python", "Linux", "PostgreSQL", "MySQL", "Oracle Database", "Microsoft SQL Server", "GitLab CI", "Jenkins", "GitHub Actions", "NGINX", "ELK Stack", "GIT", "Apache Kafka", "MongoDB", "ClickHouse", "Tarantool", "Cassandra", "Redis", "Go", "AWS", "SQL", "GITLab", "SonarQube", "Allure", "Azure DevOps", "HAProxy", "JAVA", "ArgoCD", "Flux", "TCP", "JIRA", "Apache", …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 2/4 для DevOps-инженер
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 668 column 5 (char 23335)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "IaC",
#     "Prometheus",
#     "Grafana",
#     "ELK",
#     "ASOC",
#     "OOP",
#     "IAM",
#     "VMware vSphere",
#     "ESXi",
#     "VLAN",
#     "Apache Flink",
#     "Patroni",
#     "repmgr",
#     "Multi-tenant k8s",
#     "Flink Dashboard",
#     "Spark History Server",
#     "ZFS",
#     "Gitlab CI/CD",
#     "Jupyterhub",
#     "Coder",
#     "Scaleway",
#     "VPN NetBird",
#     "Nix package manager",
#     "AWS Graviton",
#     "Devbox",
#     "PostgreSQL",
#     "OpenSearch",
#     "HA",
#     "VLAN",
#     "Ing …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 3/4 для DevOps-инженер
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 2 column 19159 (char 19160)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": ["Kubernetes", "Docker", "Terraform", "Ansible", "Prometheus", "Grafana", "GitLab CI/CD", "Jenkins", "AWS", "Azure", "PostgreSQL", "MySQL", "Redis", "Kafka", "RabbitMQ", "Nginx", "ELK", "OpenSearch", "Git", "Python", "Bash", "Shell", "Linux", "CentOS", "Ubuntu", "Debian", "RedHat", "Helm", "Kubectl", "Kubespray", "K3s", "GKE", "EKS", "Minikube", "ArgoCD", "Flux", "Promtail", "Loki", "AlertManager", "Zabbix", "ClickHouse", "Consul", "Keycloak", "Postfix", "Sendmail", "PowerDNS", "F …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 4/4 для DevOps-инженер
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# ✅ Final base_anchors для DevOps-инженер: 49 якорей
# 📋 Дополнительная обработка 1825 навыков для DevOps-инженер
# 📦 Обрабатываю чанк 1/7 для DevOps-инженер (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 2/7 для DevOps-инженер (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 3/7 для DevOps-инженер (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 4/7 для DevOps-инженер (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 5/7 для DevOps-инженер (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 6/7 для DevOps-инженер (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 7/7 для DevOps-инженер (25 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# ✅ DevOps-инженер: {'total_skills': 1878, 'mapped': 388, 'unmapped': 43, 'base_anchors': 49, 'remaining_sent': 1825}
#
# ==================================================
# 🚀 Обработка позиции 2/2: Программист, разработчик
# ==================================================
# 🎯 Начинаю обработку Программист, разработчик: 11694 уникальных навыков
# 🔍 Обрабатываю чанк 1/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 431 column 5 (char 20612)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "GIT",
#     "GitLab",
#     "PostgreSQL",
#     "MySQL",
#     "MariaDB",
#     "Docker",
#     "JavaScript",
#     "JQuery",
#     "Docker-compose",
#     "SQL",
#     "Async Python",
#     "PL/SQL",
#     "C#",
#     ".NET",
#     "EF",
#     "WebAPI",
#     "Swagger",
#     "ElasticSearch",
#     "RabbitMQ",
#     "Redis",
#     "СКЗИ КриптоПро CSP",
#     "Express",
#     "Nest.js",
#     "TypeScript",
#     "PHP",
#     "GitLab CI/CD",
#     "HTML",
#     "CSS",
#     "SASS",
#     "Python",
#     "1С",
#     "Java",
#     "Kotlin" …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 2/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 647 column 5 (char 11519)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1С",
#     "1С:Бухгалтерия",
#     "1С:Управление торговлей",
#     "1С:Зарплата и управление персоналом",
#     "1С:ERP",
#     "1С:Комплексная Автоматизация",
#     "1С:Управление Холдингом",
#     "1С:Документооборот",
#     "1С:Предприятие",
#     "1С:УТ",
#     "1С:БП",
#     "1С:УНФ",
#     "1С:Розница",
#     "1С:БСП",
#     "1С:УХ",
#     "1С:УПП",
#     "1С:КА",
#     "1С:БУХ",
#     "1С:ЗУП",
#     "1С:УТ 11",
#     "1С:БП 3.0",
#     "1С:ЗУП 3.1",
#     "1С:УНФ 1.6",
#     "1С:УПП 1.3",
#     "1С:УТ 11.5",
#     …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 3/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 1541 column 14 (char 22318)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "Java SE",
#     "Spring",
#     "JavaScript",
#     "React",
#     "Angular",
#     "PHP",
#     "Python",
#     "1С",
#     "SQL",
#     "PostgreSQL",
#     "Git",
#     "Docker",
#     "Linux",
#     "CSS",
#     "HTML",
#     "TypeScript",
#     "Node.js",
#     "REST API",
#     "SOAP",
#     "Bitrix",
#     "Kotlin",
#     "Scala",
#     "C++",
#     "C#",
#     "Swift",
#     "Objective-C",
#     "Delphi",
#     "MATLAB",
#     "Sass",
#     "Less",
#     "Stylus",
#     "Bootstrap",
#     "Gulp",
#     "WebSocket",
#     "GraphQL",
#   …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 4/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 54 column 18 (char 992)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1С",
#     "1С:Предприятие 8.3 УПП, ЗУП",
#     "1С:ERP",
#     "1С:УТ",
#     "1С:БП",
#     "1С:ЗУП",
#     "1С:Документооборот",
#     "1С:Управление торговлей",
#     "1С:Управление нашей фирмой",
#     "1С:Комплексная автоматизация",
#     "1С:БГУ",
#     "1С:Бухгалтерия предприятия 3",
#     "1С:УПП",
#     "1С:ВЭД",
#     "1С:Закупки",
#     "1С:TMS",
#     "1С:УАТ",
#     "1С:УТ 11",
#     "1С:УТ 10",
#     "1С:УТ 11.5",
#     "1С:УТ 10.3",
#     "1С:УТ 11.5",
#     "1С:УТ 11.5",
#     "1С:УТ 11.5",
#     "1С:УТ  …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 5/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 64 column 36 (char 1881)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1С",
#     "1С:ERP",
#     "1С:Бухгалтерия",
#     "1С:Документооборот",
#     "1С:Зарплата и управление персоналом",
#     "1С:Управление торговлей",
#     "1С:CRM",
#     "1С:БИТ",
#     "1С:КА",
#     "1С:Розница",
#     "1С:УТ",
#     "1С:УПП",
#     "1С:УХ",
#     "1С:ЗУП",
#     "1С:БП",
#     "1С:Конвертация данных",
#     "1С:Шина",
#     "1С:Специалист",
#     "1С:Профессионал",
#     "1С:Предприятие",
#     "1С:СКД",
#     "1С:Специалист по платформе 8",
#     "1С:Управление производственным предприятием",
#  …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 6/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 537 column 27 (char 14046)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1C",
#     "1C:ERP",
#     "1C:ЗУП",
#     "1C:БП",
#     "1C:УТ",
#     "1C:УПП",
#     "1C:КА",
#     "1C:СППР",
#     "1C:УСП",
#     "1C:Документооборот",
#     "1C:Зарплата и кадры",
#     "1C:Предприятие",
#     "1C:EDT",
#     "1C:КД",
#     "1C:УНФ",
#     "1C:Битрикс",
#     "1C:ERP Управление предприятием 2",
#     "1C:ERP УХ",
#     "1C:ERP Управление предприятием 2.4",
#     "1C:Предприятие 8.2",
#     "1C:Предприятие 8.3",
#     "1C:Предприятие 8.2/8.3",
#     "1C:Предприятие 8.3+",
#     "1C:Предприятие 8 …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 7/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 8/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 45 column 15 (char 660)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1С",
#     "1С:Предприятие",
#     "1С:ERP",
#     "1С:Бухгалтерия",
#     "1С:УТ",
#     "1С:ЗУП",
#     "1С:УАТ",
#     "1С:КА",
#     "1С:ТОиР",
#     "1С:УПП",
#     "1С:УНФ",
#     "1С:УПК",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#     "1С:УПЦБ",
#      …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 9/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 58 column 30 (char 1358)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "JavaScript/ES6",
#     "Vue 2 + Vuex",
#     "Vue.jsNuxt.js",
#     "React 16+",
#     "ReactContext",
#     "ReactAdmin",
#     "React-query",
#     "Vue-cli",
#     "Vuex",
#     "Vue.js",
#     "Nuxt.js",
#     "Vue",
#     "HTML-верстка",
#     "HTML HTML5",
#     "HTML+JS+CSS",
#     "CSS",
#     "JS6",
#     "Pug Jade",
#     "Float",
#     "API Яндекс",
#     "API",
#     "API JSON",
#     "API REST",
#     "API RESTful",
#     "API RESTLike",
#     "API биржевых котировок",
#     "API биржевых котировок",
#     "API би …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 10/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 771 column 19 (char 23026)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "K8s/Openshift",
#     "Bash/zsh",
#     "Микро-сервисы",
#     "ОС на базе ядра Linux",
#     "Modbus RTU/TCP",
#     "Windows Presentation Foundation WPF",
#     "Windows Communication Foundation WCF",
#     "ModBus ASCII",
#     "UPD",
#     "SOAP/WCF",
#     "Project Server SSOM/CSOM/JSOM",
#     "Etcd",
#     "CockroachDB",
#     "Kerberos",
#     "IETF RFC",
#     "CORBA",
#     "BPF-фильтров",
#     "GNU C Library POSIX.1",
#     "Libstdc++ с++11",
#     "WCF сервисы",
#     "DI-контейнеры",
#     "C4",
#     " …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 11/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 695 column 19 (char 15499)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "HTTP",
#     "REST",
#     "TCP/IP",
#     "TestRail",
#     "WinPcap",
#     "Soft-switch",
#     "Require.js",
#     "System.js",
#     "1C",
#     "Tronpy",
#     "Laravel",
#     "S/C++",
#     "Inertia.js",
#     "Blade",
#     "Yandex.Cloud",
#     "AWS",
#     "SaaS",
#     "QT",
#     "Cortex-M",
#     "Smart-contracts",
#     "Web3",
#     "ReactQuery",
#     "SCSS",
#     "UnoCSS",
#     "Nuxt",
#     "UDR",
#     "Reactphp",
#     "Node.js",
#     "PHP",
#     "ASP.NET",
#     "SQL",
#     "Sysinternals",
#     "Xperf",
#     " …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 12/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 53 column 17 (char 939)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1С",
#     "1С:Бухгалтерия",
#     "1С:ЗУП",
#     "1С:Управление торговлей",
#     "1С:ERP",
#     "1С:CRM",
#     "1С:Документооборот",
#     "1С:УТИВСК",
#     "1С:Аналитика",
#     "1С:БП",
#     "1С:Управление Холдингом",
#     "1С:Итилиум",
#     "1С:Астор",
#     "1С:Бит Финанс",
#     "1С:Управление Ветеринарными сертификатами",
#     "1С:УТ11",
#     "1С:УТ10.3",
#     "1С:УТ11.3",
#     "1С:УТ11.4",
#     "1С:УТ8",
#     "1С:УТИВСК",
#     "1С:УТИВСК",
#     "1С:УТИВСК",
#     "1С:УТИВСК",
#     "1С:УТИВСК",
#    …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 13/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 561 column 5 (char 11002)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1С",
#     "1С:ERP",
#     "1С:УТ",
#     "1С:ЗУП",
#     "1С:БП",
#     "1С:КД",
#     "1С:УПП",
#     "1С:ДО",
#     "1С:Розница",
#     "1С:ЮТД",
#     "1С:Ломбард",
#     "1С:Корп",
#     "1С:Бухгалтерия",
#     "1С:УТ 10.3",
#     "1С:УТ 11",
#     "1С:УТ 11.3",
#     "1С:УТ 11.4",
#     "1С:УТ 11.5",
#     "1С:УТ 11.6",
#     "1С:УТ 11.7",
#     "1С:УТ 11.8",
#     "1С:УТ 11.9",
#     "1С:УТ 11.10",
#     "1С:УТ 11.11",
#     "1С:УТ 11.12",
#     "1С:УТ 11.13",
#     "1С:УТ 11.14",
#     "1С:УТ 11.15",
#     "1С:УТ 11.16", …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 14/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting ':' delimiter: line 331 column 11 (char 5970)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "ChatGPT",
#     "GigaChat",
#     "YaGPT",
#     "JSON",
#     "Markdown",
#     "Creatio",
#     "Elasticsearch",
#     "MS Outlook",
#     "Laravel",
#     "Java SE",
#     "LMS",
#     "Fintech",
#     "Motion",
#     "SaasS",
#     "TradingView",
#     "Nuxt3",
#     "Docker",
#     "Debian",
#     "Astra",
#     "Bitrix24",
#     "Delphi",
#     "OpenNebula",
#     "TradingView",
#     "Nuxt3",
#     "Docker",
#     "Debian",
#     "Astra",
#     "Bitrix24",
#     "Delphi",
#     "OpenNebula",
#     "MongoDB",
#     "ElasticSearc …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 15/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting value: line 56 column 28 (char 1344)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1С:Предприятие",
#     "1С:Битрикс",
#     "1С:Документооборот",
#     "1С:ERP",
#     "1С:УТ",
#     "1С:БП",
#     "1С:ЗУП",
#     "1С:КА",
#     "1С:УНФ",
#     "1С:Отель",
#     "1С:Общепит",
#     "1С:Бухгалтерия предприятия",
#     "1С:Управление предприятием общепита",
#     "1С:Камин",
#     "1С:ДО",
#     "1С:ДО 2.1",
#     "1С:ДО 3.0",
#     "1С:БГУ",
#     "1С:БитФинанс",
#     "1С:Финанс.Холдинг",
#     "1С:Предприятие 8.3",
#     "1С:Предприятие 8.3.х",
#     "1С:Предприятие 8.2",
#     "1С:Предприятие 8.3 …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 16/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 678 column 17 (char 21483)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "Emotion CSS-in-JS",
#     "React Query 3",
#     "Nunjucks",
#     "TypeScript",
#     "Tailwind CSS",
#     "SSR",
#     "Kinesis",
#     "AWS",
#     "Redshift",
#     "OpenID Connect",
#     "Tableau",
#     "SSP",
#     "Serverless",
#     "AI/ML",
#     "SuperSet",
#     "JavaScript",
#     "Less/sass",
#     "ПЛК",
#     "STEP",
#     "DataLife Engine",
#     "Webasyst",
#     "Mod X",
#     "OneScript",
#     "D-LINK",
#     "UserGate",
#     "TING",
#     "Panasonic",
#     "Элтекс",
#     "Synology",
#     "SIM800",
#     " …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 17/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 766 column 30 (char 22631)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "SQLAlchemy",
#     "React",
#     "Redis",
#     "MinIO",
#     "Yii2",
#     "ClickHouse",
#     "Kafka",
#     "Manticore",
#     "BITRIX framework",
#     "FastAPI",
#     "Android",
#     "1С",
#     "Spring Boot",
#     "Jasper templates",
#     "Mapstruct",
#     "Java",
#     "PostgreSQL",
#     "MongoDB",
#     "Open Street Maps",
#     "GraalVM",
#     "Jetpack",
#     "ROS",
#     "3d камеры",
#     "ECM-системы",
#     "Vue",
#     "Groovy",
#     "JQ",
#     "Lldb",
#     "Clang-Tidy",
#     "Lxml",
#     "Qpid",
#     "Ku …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 18/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting ':' delimiter: line 601 column 81 (char 15471)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "Qt 6",
#     "English",
#     "Salt",
#     "Chef",
#     "Infinispan",
#     "JS ES 6+",
#     "MobX",
#     "Ant-design",
#     "ng-zorro",
#     "JUNIT5",
#     "BitBucket",
#     "GitHub",
#     "VS Code",
#     "Python3.x",
#     "Python 2.7",
#     "React/Vue",
#     "Lighthouse GraphQL",
#     "Catboost",
#     "Gqlgen",
#     "Proto",
#     "Cypher",
#     "Neo4J",
#     "AWS",
#     "Google Cloud",
#     "Cri-o",
#     "Rancher",
#     "Rkt",
#     "Docktrine",
#     "API Platform",
#     "HTML/CSS/SASS",
#     "Laravel 5.* …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 19/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting property name enclosed in double quotes: line 148 column 31 (char 3365)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "1С",
#     "Apache",
#     "ASP.NET",
#     "AutoCAD",
#     "Bitrix",
#     "Blade",
#     "Boost",
#     "C/C++",
#     "CMake",
#     "ComfyUI",
#     "Cortex",
#     "CSS",
#     "Debian",
#     "Eplan",
#     "Entity Framework",
#     "Exasol",
#     "Firebase",
#     "FlutterFlow",
#     "Git",
#     "Google API",
#     "Google Tables",
#     "GPS",
#     "HTML",
#     "IPTables",
#     "Java",
#     "JavaScript",
#     "JQuery",
#     "Kendo React UI",
#     "Kaiten",
#     "Laravel",
#     "Linux",
#     "MATLAB",
#     "Meilise …
# ✅ Успешный JSON ответ (попытка 1)
# 🔍 Обрабатываю чанк 20/20 для Программист, разработчик
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Unterminated string starting at: line 523 column 5 (char 21156)
# 📋 Ответ как есть (первые 500 символов): {
#   "anchors": [
#     "Simdjson",
#     "SLAM",
#     "C++",
#     "Python",
#     "FastAPI",
#     "Bootstrap5",
#     "Go",
#     "SQL",
#     "1С",
#     "Agile",
#     "Scrum",
#     "Kanban",
#     "CRM",
#     "1C:ERP",
#     "1C:ZUP",
#     "1C:WMS",
#     "1C:EHS",
#     "1C:СКД",
#     "RPC",
#     "GRPC",
#     "ASP.NET",
#     "NoSQL",
#     "MongoDB",
#     "Cassandra",
#     "SCADA",
#     "Google Tag Manager",
#     "Facebook Pixel",
#     "Cpanel",
#     "PHP",
#     "Yii",
#     "SCADA Infinity",
#     "Nuxt",
#     "Windi CSS",
#     "WebWorker …
# ✅ Успешный JSON ответ (попытка 1)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# ✅ Final base_anchors для Программист, разработчик: 25 якорей
# 📋 Дополнительная обработка 11655 навыков для Программист, разработчик
# 📦 Обрабатываю чанк 1/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 2/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 3/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 4/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 5/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 6/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 7/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 8/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 9/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 10/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 11/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 12/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting ':' delimiter: line 42 column 32 (char 1536)
# 📋 Ответ как есть (первые 500 символов): {
#   "mapping": {
#     "DataLens": "Other",
#     "Memory_profiler": "Other",
#     "Dottrace": "Other",
#     "Cprofile": "Other",
#     "NoSQL MongoDB": "NoSQL MongoDB",
#     "T-SQL Microsoft SQL Server": "MS SQL",
#     "Agile: Scrum, Kanban": "Agile",
#     "VictoriaMetrics": "Other",
#     "JS и фреймворки Vue.js": "Vue.js",
#     "CI/CD Jenkins, GitLab CI, CircleCI": "DevOps",
#     "XHTML": "Other",
#     "1с-программирование": "Other",
#     "Linux/Debian": "Other",
#     "MOODLE": "Other",
#     "типовые конфигурац …
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 13/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 14/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 15/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 16/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 17/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting ':' delimiter: line 251 column 39 (char 9483)
# 📋 Ответ как есть (первые 500 символов): {
#   "mapping": {
#     "Sungero Development Studio": "Other",
#     "Алгоритмичные решения": "Other",
#     "Опыт диагностики неисправностей в ПК": "Other",
#     "Понимание сетевых технологий": "Other",
#     "Уверенное владение ПК, знание операционных систем включая Linux, основ администрирования и работы с периферийным оборудованием": "Other",
#     "Высшее техническое образование в сфере IT, электроники или смежных областях": "Other",
#     "Знание принципов работы электроники, умение разбираться в электр …
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 18/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting ':' delimiter: line 249 column 34 (char 8729)
# 📋 Ответ как есть (первые 500 символов): {
#   "mapping": {
#     "Jasper Reports": "Other",
#     "JSF": "Other",
#     "Apache Jersey": "Other",
#     "Gerrit": "Other",
#     "ReactAdmin": "React-i18next",
#     "FastApi/Flask": "Other",
#     "Java Java 11+": "Java",
#     "БУ": "Other",
#     "Написание обменов для программ 1с": "Other",
#     "Разработка технических проектов": "Other",
#     "StarRocks": "Other",
#     "Разработка новых функциональных подсистем": "Other",
#     "Среда *nix": "Other",
#     "Организация эффективной программной разработки": "Ot …
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 19/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 20/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 21/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 22/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 23/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting ',' delimiter: line 196 column 10 (char 7829)
# 📋 Ответ как есть (первые 500 символов): {
#   "mapping": {
#     "Сопровождение кода": "Other",
#     "принципы REST": "REST API",
#     "SQL PostgreSQL/MySQL": "Other",
#     "Основы цифровой и аналоговой электроники, основы схемотехники": "Other",
#     "Основы статистической радиотехники": "Other",
#     "Распределительные вычислительные системы": "Other",
#     "Bazzar": "Other",
#     "Графический интерфейс пользователя": "Other",
#     "Специализированные модули 1С": "Other",
#     "Подготовка нормативно-технической документации": "Other",
#     "Матем …
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 24/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 25/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 26/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ⚠️ Не удалось распарсить JSON: Expecting ':' delimiter: line 296 column 11 (char 11261)
# 📋 Ответ как есть (первые 500 символов): {
#   "mapping": {
#     "Обмены используя http-сервисы": "REST API",
#     "Gamma": "Other",
#     "Pika": "Other",
#     "DALL·E": "Other",
#     "ElevenLabs": "Other",
#     "MidJourney": "Other",
#     "Canva AI": "Other",
#     "Runway": "Other",
#     "Tome": "Other",
#     "1С БП 3.х": "Other",
#     "Технологические вопросы высоконагруженных систем на базе платформы 1с": "Other",
#     "администрирование СУБД и инфраструктуры ИТ": "Other",
#     "O-data": "Other",
#     "Высоконагруженные конфигурации": "Other",
#      …
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 27/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 28/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 29/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 30/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 31/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 32/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 33/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 34/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 35/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 36/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 37/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 38/39 для Программист, разработчик (300 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# 📦 Обрабатываю чанк 39/39 для Программист, разработчик (255 навыков)
# 🔄 Попытка 1 для запроса к LLM
# ✅ Успешный JSON ответ (попытка 1)
# ✅ Программист, разработчик: {'total_skills': 11694, 'mapped': 866, 'unmapped': 1643, 'base_anchors': 25, 'remaining_sent': 11655}
# Готово. Сохранено в stage_5_df_train_result_skills_mapping_V6_2.csv
